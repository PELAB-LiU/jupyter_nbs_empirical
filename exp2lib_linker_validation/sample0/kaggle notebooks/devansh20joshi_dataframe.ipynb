# %% [markdown]
# # Update Values in Dataframe

# %%
import pandas as pd

# %%
data = pd.read_csv("/kaggle/input/data-science-jobs-in-india/naukri_data_science_jobs_india.csv",index_col = ["Job_Role"])
data
# Out:
#                                                                                Company  \
# Job_Role
# Senior Data Scientist                                                              UPL
# Senior Data Scientist                                                          Walmart
# Applied Data Scientist / ML Senior Engineer (Py...                   SAP India Pvt.Ltd
# Data Scientist                                                                     UPL
# Data Scientist                                                                 Walmart
# ...                                                                                ...
# Tech Lead/Architect ( Contractual )                 Krazy Mantra HR Solutions Pvt. Ltd
# Tech Lead / POD Lead                                                        cliqhr.com
# Java Full Stack Developer - Hibernate / Spring                           Serving Skill
# Tech Lead - Azure                                                           cliqhr.com
# ...

# %% [markdown]
# **Update a cell value**

# %%
data.loc["Tech Lead - Azure","Company"] = "CliqHR.com"

# %%
data.tail(3)
# Out:
#                                                                   Company  \
# Job_Role
# Java Full Stack Developer - Hibernate / Spring              Serving Skill
# Tech Lead - Azure                                              CliqHR.com
# Full Stack Developer - Machine Learning         Huquo Consulting Pvt. Ltd
#
#                                                                                          Location  \
# Job_Role
# Java Full Stack Developer - Hibernate / Spring        Hyderabad/Secunderabad, Bangalore/Bengaluru
# Tech Lead - Azure                               Kochi/Cochin, Mumbai, Hyderabad/Secunderabad, ...
# Full Stack Developer - Machine Learning                                       Bangalore/Bengaluru
#
#                                                Job Experience  \
# Job_Role
# Java Full Stack Developer - Hibernate / Spring            2-5
# Tech Lead - Azure                                        8-10
# ...

# %%
data.loc["Senior Data Scientist",["Location","Job Experience"]] = ["Bengaluru","3-6"]

# %%
data.loc["Senior Data Scientist",["Location","Job Experience"]]
# Out:
#                         Location Job Experience
# Job_Role
# Senior Data Scientist  Bengaluru            3-6
# Senior Data Scientist  Bengaluru            3-6
# Senior Data Scientist  Bengaluru            3-6
# Senior Data Scientist  Bengaluru            3-6
# Senior Data Scientist  Bengaluru            3-6
# ...                          ...            ...
# Senior Data Scientist  Bengaluru            3-6
# Senior Data Scientist  Bengaluru            3-6
# Senior Data Scientist  Bengaluru            3-6
# Senior Data Scientist  Bengaluru            3-6
# Senior Data Scientist  Bengaluru            3-6
#
# [97 rows x 2 columns]

# %% [markdown]
# **rename all Bangalore to Bangaluru**

# %%
mask = data.loc[:,"Location"].isin(["Bangalore","Bangalore/Bengaluru"])

# %%
data.loc[mask,"Location"] = "Bengaluru"

# %%
data
# Out:
#                                                                                Company  \
# Job_Role
# Senior Data Scientist                                                              UPL
# Senior Data Scientist                                                          Walmart
# Applied Data Scientist / ML Senior Engineer (Py...                   SAP India Pvt.Ltd
# Data Scientist                                                                     UPL
# Data Scientist                                                                 Walmart
# ...                                                                                ...
# Tech Lead/Architect ( Contractual )                 Krazy Mantra HR Solutions Pvt. Ltd
# Tech Lead / POD Lead                                                        cliqhr.com
# Java Full Stack Developer - Hibernate / Spring                           Serving Skill
# Tech Lead - Azure                                                           CliqHR.com
# ...

# %% [markdown]
# # Index Rename
#
# **We can Reame index or Column Name**
#
# * Mapper + Axis
# * Index + Column

# %% [markdown]
# **Mapper + Axis**

# %%
data = pd.read_csv("/kaggle/input/data-science-jobs-in-india/naukri_data_science_jobs_india.csv",index_col = ["Job_Role"])

# %%
data
# Out:
#                                                                                Company  \
# Job_Role
# Senior Data Scientist                                                              UPL
# Senior Data Scientist                                                          Walmart
# Applied Data Scientist / ML Senior Engineer (Py...                   SAP India Pvt.Ltd
# Data Scientist                                                                     UPL
# Data Scientist                                                                 Walmart
# ...                                                                                ...
# Tech Lead/Architect ( Contractual )                 Krazy Mantra HR Solutions Pvt. Ltd
# Tech Lead / POD Lead                                                        cliqhr.com
# Java Full Stack Developer - Hibernate / Spring                           Serving Skill
# Tech Lead - Azure                                                           cliqhr.com
# ...

# %%
data.rename(mapper = {"Senior Data Scientist":"Senior Data Analyst",
                     "Data Scientist":" Data Analyst"},axis = 0,inplace = True)  #axis = 0

# %%
data.head()
# Out:
#                                                               Company  \
# Job_Role
# Senior Data Analyst                                               UPL
# Senior Data Analyst                                           Walmart
# Applied Data Scientist / ML Senior Engineer (Py...  SAP India Pvt.Ltd
#  Data Analyst                                                     UPL
#  Data Analyst                                                 Walmart
#
#                                                                                    Location  \
# Job_Role
# Senior Data Analyst                                 Bangalore/Bengaluru, Mumbai (All Areas)
# Senior Data Analyst                                                     Bangalore/Bengaluru
# Applied Data Scientist / ML Senior Engineer (Py...                      Bangalore/Bengaluru
#  Data Analyst                                       Bangalore/Bengaluru, Mumbai (All Areas)
# ...

# %% [markdown]
# **index + Column**

# %%
data.rename(index = {"Senior Data Analyst":"Senior Data Scientist",
                     " Data Analyst":"Data Scientist"},inplace = True)

# %%
data
# Out:
#                                                                                Company  \
# Job_Role
# Senior Data Scientist                                                              UPL
# Senior Data Scientist                                                          Walmart
# Applied Data Scientist / ML Senior Engineer (Py...                   SAP India Pvt.Ltd
# Data Scientist                                                                     UPL
# Data Scientist                                                                 Walmart
# ...                                                                                ...
# Tech Lead/Architect ( Contractual )                 Krazy Mantra HR Solutions Pvt. Ltd
# Tech Lead / POD Lead                                                        cliqhr.com
# Java Full Stack Developer - Hibernate / Spring                           Serving Skill
# Tech Lead - Azure                                                           cliqhr.com
# ...

# %% [markdown]
# # **Column Rename**

# %% [markdown]
# **Using Mapper and axis**

# %%
data = pd.read_csv("/kaggle/input/data-science-jobs-in-india/naukri_data_science_jobs_india.csv",index_col = ["Job_Role"])

# %%
data.head()
# Out:
#                                                               Company  \
# Job_Role
# Senior Data Scientist                                             UPL
# Senior Data Scientist                                         Walmart
# Applied Data Scientist / ML Senior Engineer (Py...  SAP India Pvt.Ltd
# Data Scientist                                                    UPL
# Data Scientist                                                Walmart
#
#                                                                                    Location  \
# Job_Role
# Senior Data Scientist                               Bangalore/Bengaluru, Mumbai (All Areas)
# Senior Data Scientist                                                   Bangalore/Bengaluru
# Applied Data Scientist / ML Senior Engineer (Py...                      Bangalore/Bengaluru
# Data Scientist                                      Bangalore/Bengaluru, Mumbai (All Areas)
# ...

# %%
data.rename(mapper = {"Company":"Firm",
                     "Skills/Description":"Job Requirement"},axis = 1,inplace =True)

# %%
data.columns
# Out:
# Index(['Firm', 'Location', 'Job Experience', 'Job Requirement'], dtype='object')

# %%
data.rename(columns = {"Firm":"Company",
                     "Job Requirement":"Skills/Description"},inplace = True)

# %%
data
# Out:
#                                                                                Company  \
# Job_Role
# Senior Data Scientist                                                              UPL
# Senior Data Scientist                                                          Walmart
# Applied Data Scientist / ML Senior Engineer (Py...                   SAP India Pvt.Ltd
# Data Scientist                                                                     UPL
# Data Scientist                                                                 Walmart
# ...                                                                                ...
# Tech Lead/Architect ( Contractual )                 Krazy Mantra HR Solutions Pvt. Ltd
# Tech Lead / POD Lead                                                        cliqhr.com
# Java Full Stack Developer - Hibernate / Spring                           Serving Skill
# Tech Lead - Azure                                                           cliqhr.com
# ...

# %% [markdown]
# # Delete Rows

# %%
data = pd.read_csv("/kaggle/input/data-science-jobs-in-india/naukri_data_science_jobs_india.csv",index_col = ["Job_Role"])

# %%
data
# Out:
#                                                                                Company  \
# Job_Role
# Senior Data Scientist                                                              UPL
# Senior Data Scientist                                                          Walmart
# Applied Data Scientist / ML Senior Engineer (Py...                   SAP India Pvt.Ltd
# Data Scientist                                                                     UPL
# Data Scientist                                                                 Walmart
# ...                                                                                ...
# Tech Lead/Architect ( Contractual )                 Krazy Mantra HR Solutions Pvt. Ltd
# Tech Lead / POD Lead                                                        cliqhr.com
# Java Full Stack Developer - Hibernate / Spring                           Serving Skill
# Tech Lead - Azure                                                           cliqhr.com
# ...

# %%
data.describe()
# Out:
#           Company             Location Job Experience  \
# count       12000                12000          12000
# unique       3507                  822            143
# top     Accenture  Bangalore/Bengaluru           5-10
# freq          490                 3383            944
#
#                                        Skills/Description
# count                                               12000
# unique                                              11356
# top     Computer science, Manager Quality Assurance, F...
# freq                                                    8

# %% [markdown]
# **Drop() method**

# %%
data.drop(labels = "Senior Data Scientist",inplace = True)

# %%
data.drop(labels = "Skills/Description",axis = 1,inplace =True)

# %% [markdown]
# **Using pop method**

# %%
loc = data.pop("Location")

# %%
loc
# Out:
# Job_Role
# Applied Data Scientist / ML Senior Engineer (Python / SQL)                                  Bangalore/Bengaluru
# Data Scientist                                                          Bangalore/Bengaluru, Mumbai (All Areas)
# Data Scientist                                                                              Bangalore/Bengaluru
# Principal Data Scientist                                                                    Bangalore/Bengaluru
# Data Scientist                                                                              Bangalore/Bengaluru
#                                                                                     ...
# Tech Lead/Architect ( Contractual )                                       Kolkata, Chennai, Bangalore/Bengaluru
# Tech Lead / POD Lead                                          Hyderabad/Secunderabad, Pune, Bangalore/Bengaluru
# ...

# %%
data
# Out:
#                                                                                Company  \
# Job_Role
# Applied Data Scientist / ML Senior Engineer (Py...                   SAP India Pvt.Ltd
# Data Scientist                                                                     UPL
# Data Scientist                                                                 Walmart
# Principal Data Scientist                                                       Walmart
# Data Scientist                                                                 Walmart
# ...                                                                                ...
# Tech Lead/Architect ( Contractual )                 Krazy Mantra HR Solutions Pvt. Ltd
# Tech Lead / POD Lead                                                        cliqhr.com
# Java Full Stack Developer - Hibernate / Spring                           Serving Skill
# Tech Lead - Azure                                                           cliqhr.com
# ...

# %% [markdown]
# **using del keyword**

# %%
del data["Company"]

# %%
data
# Out:
#                                                    Job Experience
# Job_Role
# Applied Data Scientist / ML Senior Engineer (Py...           5-10
# Data Scientist                                                1-4
# Data Scientist                                                4-8
# Principal Data Scientist                                     7-12
# Data Scientist                                                4-8
# ...                                                           ...
# Tech Lead/Architect ( Contractual )                          8-13
# Tech Lead / POD Lead                                        10-12
# Java Full Stack Developer - Hibernate / Spring                2-5
# Tech Lead - Azure                                            8-10
# Full Stack Developer - Machine Learning                      5-10
#
# [11903 rows x 1 columns]

# %% [markdown]
# # Random Sampling

# %%
data = pd.read_csv("/kaggle/input/data-science-jobs-in-india/naukri_data_science_jobs_india.csv",index_col = ["Job_Role"])

# %%
data
# Out:
#                                                                                Company  \
# Job_Role
# Senior Data Scientist                                                              UPL
# Senior Data Scientist                                                          Walmart
# Applied Data Scientist / ML Senior Engineer (Py...                   SAP India Pvt.Ltd
# Data Scientist                                                                     UPL
# Data Scientist                                                                 Walmart
# ...                                                                                ...
# Tech Lead/Architect ( Contractual )                 Krazy Mantra HR Solutions Pvt. Ltd
# Tech Lead / POD Lead                                                        cliqhr.com
# Java Full Stack Developer - Hibernate / Spring                           Serving Skill
# Tech Lead - Azure                                                           cliqhr.com
# ...

# %%
data.sample()
# Out:
#                      Company Location Job Experience  \
# Job_Role
# Data Engineer  Priceline.com   Mumbai            1-3
#
#                                               Skills/Description
# Job_Role
# Data Engineer  Computer science, Customer acquisition, ERP, D...

# %% [markdown]
# **Multiple Rows**

# %%
data.sample(n = 10)
# Out:
#                                                                        Company  \
# Job_Role
# Business Analyst                                                  ITC Infotech
# Senior Analyst-Data Visualization                                    Accenture
# Azure Engineer - Data Warehousing/DataLake                           DataToBiz
# Associate Data Scientist                                 Right Step Consulting
# Data Scientist                              Ashkom Media India Private Limited
# Data Modeler                                                Schneider Electric
# Senior Data Engineer                                                     Ciena
# Need immediate joiners- PMO Analyst                            Hucon Solutions
# Senior Analyst, Data Engineering                             Dell Technologies
# Data Engineer                                   3D PLM Software Solutions Ltd.
#
# ...

# %% [markdown]
# **Random Column**

# %%
data.sample(n = 2,axis = 1)
# Out:
#                                                                                Company  \
# Job_Role
# Senior Data Scientist                                                              UPL
# Senior Data Scientist                                                          Walmart
# Applied Data Scientist / ML Senior Engineer (Py...                   SAP India Pvt.Ltd
# Data Scientist                                                                     UPL
# Data Scientist                                                                 Walmart
# ...                                                                                ...
# Tech Lead/Architect ( Contractual )                 Krazy Mantra HR Solutions Pvt. Ltd
# Tech Lead / POD Lead                                                        cliqhr.com
# Java Full Stack Developer - Hibernate / Spring                           Serving Skill
# Tech Lead - Azure                                                           cliqhr.com
# ...

# %% [markdown]
# **Frac argument**

# %%
data.describe()
# Out:
#           Company             Location Job Experience  \
# count       12000                12000          12000
# unique       3507                  822            143
# top     Accenture  Bangalore/Bengaluru           5-10
# freq          490                 3383            944
#
#                                        Skills/Description
# count                                               12000
# unique                                              11356
# top     Computer science, Manager Quality Assurance, F...
# freq                                                    8

# %%
data.sample(frac = 0.1)
# Out:
#                                                                                   Company  \
# Job_Role
# Sr Engineer - Data Center Hardware - USA - MNC ...  Vesat Management Consultants Pvt. Ltd
# Data Engineer                                                   CHANGE LEADERS CONSULTING
# Data Analyst                                                                     referral
# NSMX - 6011 - Data Analyst - Open End Coding / ...            NS Matrix Services Pvt. Ltd
# Staff Data Engineer - Data Analytics & Reporting                                  Walmart
# ...                                                                                   ...
# Big Data Engineer                                                     Xebia IT Architects
# Ld. DB Dev                                                                     BNY Mellon
# Machine Learning Engineer                                                            Pype
# ...

# %% [markdown]
# **Replace argument - same row can be selected more than once**

# %%
data.sample(n =10,replace = True)
# Out:
#                                                                                     Company  \
# Job_Role
# Analyst - C++/Linux/Data Structure - L2 Support                   Huquo Consulting Pvt. Ltd
# Big data Engineer                                        TeamPlus Staffing Solution Pvt Ltd
# Software Development Engineer II - IOS                                         Zendrive Inc
# Sr. UX Research Analyst                                                            Anicalls
# Senior Data Analyst                                                         Thomson Reuters
# Senior Technical Lead (Data Engineer)                       Infostretch solutions Pvt. Ltd.
# Data Scientist                                                                    Version 1
# Data Scientist                                                 RGF Professional Recruitment
# Data Engineer AWS                                Search Advisers Services ( GUJ ) Pvt. Ltd.
# ...

# %% [markdown]
# # Largest/Smallest Value

# %%
import numpy as np

# %%
data = pd.read_csv("/kaggle/input/data-science-jobs-in-india/naukri_data_science_jobs_india.csv",index_col = ["Job_Role"])

# %%
data["Salary"] = np.random.randint(400000,4000000,size = 12000)

# %%
data
# Out:
#                                                                                Company  \
# Job_Role
# Senior Data Scientist                                                              UPL
# Senior Data Scientist                                                          Walmart
# Applied Data Scientist / ML Senior Engineer (Py...                   SAP India Pvt.Ltd
# Data Scientist                                                                     UPL
# Data Scientist                                                                 Walmart
# ...                                                                                ...
# Tech Lead/Architect ( Contractual )                 Krazy Mantra HR Solutions Pvt. Ltd
# Tech Lead / POD Lead                                                        cliqhr.com
# Java Full Stack Developer - Hibernate / Spring                           Serving Skill
# Tech Lead - Azure                                                           cliqhr.com
# ...

# %%
data.sort_values("Salary",ascending = False).head(3)
# Out:
#                                                                         Company  \
# Job_Role
# MNC Hiring For " Data Scientist & cloud " - Gur...         ESS CEE HR SOLUTIONS
# Technical Analyst                                          Telamon HR Solutions
# Hiring For Data Engineer - with Service Based C...  Symphoni HR Private Limited
#
#                                                                      Location  \
# Job_Role
# MNC Hiring For " Data Scientist & cloud " - Gur...  Gurgaon/Gurugram, Chennai
# Technical Analyst                                                      Mumbai
# Hiring For Data Engineer - with Service Based C...        Bangalore/Bengaluru
#
#                                                    Job Experience  \
# Job_Role
# MNC Hiring For " Data Scientist & cloud " - Gur...           5-10
# Technical Analyst                                             3-7
# Hiring For Data Engineer - with Service Based C...            6-8
#
# ...

# %%
data.nlargest(3,"Salary")
# Out:
#                                                                         Company  \
# Job_Role
# MNC Hiring For " Data Scientist & cloud " - Gur...         ESS CEE HR SOLUTIONS
# Technical Analyst                                          Telamon HR Solutions
# Hiring For Data Engineer - with Service Based C...  Symphoni HR Private Limited
#
#                                                                      Location  \
# Job_Role
# MNC Hiring For " Data Scientist & cloud " - Gur...  Gurgaon/Gurugram, Chennai
# Technical Analyst                                                      Mumbai
# Hiring For Data Engineer - with Service Based C...        Bangalore/Bengaluru
#
#                                                    Job Experience  \
# Job_Role
# MNC Hiring For " Data Scientist & cloud " - Gur...           5-10
# Technical Analyst                                             3-7
# Hiring For Data Engineer - with Service Based C...            6-8
#
# ...

# %%
data["Salary"].nlargest(3)
# Out:
# Job_Role
# MNC Hiring For " Data Scientist & cloud " - Gurgaon & Chennai    3999790
# Technical Analyst                                                3999169
# Hiring For Data Engineer - with Service Based Company            3999066
# Name: Salary, dtype: int64

# %%
data.sort_values("Salary").head(3)
# Out:
#                                      Company            Location  \
# Job_Role
# Data Scientist    Sapwood Ventures Pvt. Ltd.  Mumbai(Prabhadevi)
# Data Scientist                    Genie Talk              Indore
# Campaign Analyst            Nation with Namo         Delhi / NCR
#
#                  Job Experience  \
# Job_Role
# Data Scientist              2-7
# Data Scientist              3-5
# Campaign Analyst            1-5
#
#                                                  Skills/Description  Salary
# Job_Role
# Data Scientist                                     machine learning  400118
# Data Scientist    IT Skills, Python, Testing, Data Science, Mach...  400498
# Campaign Analyst  Communication Skills, networking skills, Data ...  400679

# %%
data.nsmallest(3,"Salary")
# Out:
#                                      Company            Location  \
# Job_Role
# Data Scientist    Sapwood Ventures Pvt. Ltd.  Mumbai(Prabhadevi)
# Data Scientist                    Genie Talk              Indore
# Campaign Analyst            Nation with Namo         Delhi / NCR
#
#                  Job Experience  \
# Job_Role
# Data Scientist              2-7
# Data Scientist              3-5
# Campaign Analyst            1-5
#
#                                                  Skills/Description  Salary
# Job_Role
# Data Scientist                                     machine learning  400118
# Data Scientist    IT Skills, Python, Testing, Data Science, Mach...  400498
# Campaign Analyst  Communication Skills, networking skills, Data ...  400679

# %%
data["Salary"].nsmallest(3)
# Out:
# Job_Role
# Data Scientist      400118
# Data Scientist      400498
# Campaign Analyst    400679
# Name: Salary, dtype: int64

# %% [markdown]
# # Where Method

# %%
data = pd.read_csv("/kaggle/input/data-science-jobs-in-india/naukri_data_science_jobs_india.csv")
data.head(3)
# Out:
#                                             Job_Role            Company  \
# 0                              Senior Data Scientist                UPL
# 1                              Senior Data Scientist            Walmart
# 2  Applied Data Scientist / ML Senior Engineer (P...  SAP India Pvt.Ltd
#
#                                   Location Job Experience  \
# 0  Bangalore/Bengaluru, Mumbai (All Areas)            3-6
# 1                      Bangalore/Bengaluru            5-9
# 2                      Bangalore/Bengaluru           5-10
#
#                                   Skills/Description
# 0  python, MLT, statistical modeling, machine lea...
# 1  Data Science, Machine learning, Python, Azure,...
# 2  Python, IT Skills, Testing, Cloud, Product Man...

# %%
mask = data['Job_Role'] == "Senior Data Scientist"

# %%
data[mask]
# Out:
#                    Job_Role                                         Company  \
# 0     Senior Data Scientist                                             UPL
# 1     Senior Data Scientist                                         Walmart
# 13    Senior Data Scientist  Northface Consultancy Services Private Limited
# 14    Senior Data Scientist                                        referral
# 23    Senior Data Scientist                          Revnomix Solutions LLP
# ...                     ...                                             ...
# 765   Senior Data Scientist            Idexcel Technologies Private Limited
# 768   Senior Data Scientist                      Pitney Bowes India Pvt Ltd
# 842   Senior Data Scientist               Nanobi Data And Analytics Pvt Ltd
# 1073  Senior Data Scientist                       Bigshyft Hiring for Zupee
# 1320  Senior Data Scientist                            Sysvine Technologies
#
# ...

# %% [markdown]
# **Where method**

# %%
data.where(mask)
# Out:
#                     Job_Role  Company  \
# 0      Senior Data Scientist      UPL
# 1      Senior Data Scientist  Walmart
# 2                        NaN      NaN
# 3                        NaN      NaN
# 4                        NaN      NaN
# ...                      ...      ...
# 11995                    NaN      NaN
# 11996                    NaN      NaN
# 11997                    NaN      NaN
# 11998                    NaN      NaN
# 11999                    NaN      NaN
#
#                                       Location Job Experience  \
# 0      Bangalore/Bengaluru, Mumbai (All Areas)            3-6
# 1                          Bangalore/Bengaluru            5-9
# 2                                          NaN            NaN
# 3                                          NaN            NaN
# 4                                          NaN            NaN
# ...                                        ...            ...
# 11995                                      NaN            NaN
# ...

# %% [markdown]
# **Use the where function where "the value which are False will be replaced with Nan**

# %%
df = pd.DataFrame(np.random.randint(10,100,(4,4)),index = ["Dev","ved","Aman","Taman"],columns =["Test1","Test2","Test3","Test4"] )
df
# Out:
#        Test1  Test2  Test3  Test4
# Dev       26     82     41     40
# ved       11     59     95     90
# Aman      67     73     43     86
# Taman     48     86     58     20

# %%
df<80
# Out:
#        Test1  Test2  Test3  Test4
# Dev     True  False   True   True
# ved     True   True  False  False
# Aman    True   True   True  False
# Taman   True  False   True   True

# %%
df.where(df<80,"A")
# Out:
#        Test1 Test2 Test3 Test4
# Dev       26     A    41    40
# ved       11    59     A     A
# Aman      67    73    43     A
# Taman     48     A    58    20

# %% [markdown]
# **Using series**

# %%
df
# Out:
#        Test1  Test2  Test3  Test4
# Dev       26     82     41     40
# ved       11     59     95     90
# Aman      67     73     43     86
# Taman     48     86     58     20

# %%
m = df["Test1"]<75

# %%
df.where(m,"B")
# Out:
#        Test1  Test2  Test3  Test4
# Dev       26     82     41     40
# ved       11     59     95     90
# Aman      67     73     43     86
# Taman     48     86     58     20

# %% [markdown]
# Where() method using Function

# %%
df
# Out:
#        Test1  Test2  Test3  Test4
# Dev       26     82     41     40
# ved       11     59     95     90
# Aman      67     73     43     86
# Taman     48     86     58     20

# %%
c = lambda x:x<80

# %%
c(df)
# Out:
#        Test1  Test2  Test3  Test4
# Dev     True  False   True   True
# ved     True   True  False  False
# Aman    True   True   True  False
# Taman   True  False   True   True

# %%
df.where( lambda x:x<80,"A",inplace = True)

# %%
df
# Out:
#        Test1 Test2 Test3 Test4
# Dev       26     A    41    40
# ved       11    59     A     A
# Aman      67    73    43     A
# Taman     48     A    58    20

# %% [markdown]
# **Having a Dynamic Value for other**

# %%
df
# Out:
#        Test1 Test2 Test3 Test4
# Dev       26     A    41    40
# ved       11    59     A     A
# Aman      67    73    43     A
# Taman     48     A    58    20

# %%
df.where(df>39,lambda x:x+2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 df.where(df>39,lambda x:x+2)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/ops/common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/core/frame.py:7445, in DataFrame._cmp_method(self, other, op)
#    7442 self, other = ops.align_method_FRAME(self, other, axis, flex=False, level=None)
#    7444 # See GH#4537 for discussion of scalar op behavior
# ...

# %% [markdown]
# # query method()
#
#
# Query the Columns of a dataframe with boolean expression

# %%
data = pd.read_csv("/kaggle/input/data-science-jobs-in-india/naukri_data_science_jobs_india.csv")
data.head(3)

# %%
data.query("Job_Role == 'Data Scientist'" )

# %%
data.query("`Job Experience` == '0-0'" )

# %% [markdown]
# **We can also replace the column names with space with underscore to avoid ` **

# %%
data.columns
# Out:
# Index(['Job_Role', 'Company', 'Location', 'Job Experience',
#        'Skills/Description'],
#       dtype='object')

# %%
data.columns = [i.replace(" ","_")for i in data.columns]

# %%
data
# Out:
#                                                 Job_Role  \
# 0                                  Senior Data Scientist
# 1                                  Senior Data Scientist
# 2      Applied Data Scientist / ML Senior Engineer (P...
# 3                                         Data Scientist
# 4                                         Data Scientist
# ...                                                  ...
# 11995                Tech Lead/Architect ( Contractual )
# 11996                               Tech Lead / POD Lead
# 11997     Java Full Stack Developer - Hibernate / Spring
# 11998                                  Tech Lead - Azure
# 11999            Full Stack Developer - Machine Learning
#
#                                   Company  \
# 0                                     UPL
# 1                                 Walmart
# 2                       SAP India Pvt.Ltd
# 3                                     UPL
# 4                                 Walmart
# ...

# %%
data.query("Job_Role == 'Senior Data Scientist' & Job_Experience == '3-5'")
# Out:
#                   Job_Role                          Company  \
# 537  Senior Data Scientist  Seven Consultancy (HR Solution)
#
#                    Location Job_Experience  \
# 537  Hyderabad/Secunderabad            3-5
#
#                                     Skills/Description
# 537  Computer science, C++, SAS, Coding, Perl, Data...

# %%
data.query("Job_Role in ['Senior Data Scientist']")
# Out:
#                    Job_Role                                         Company  \
# 0     Senior Data Scientist                                             UPL
# 1     Senior Data Scientist                                         Walmart
# 13    Senior Data Scientist  Northface Consultancy Services Private Limited
# 14    Senior Data Scientist                                        referral
# 23    Senior Data Scientist                          Revnomix Solutions LLP
# ...                     ...                                             ...
# 765   Senior Data Scientist            Idexcel Technologies Private Limited
# 768   Senior Data Scientist                      Pitney Bowes India Pvt Ltd
# 842   Senior Data Scientist               Nanobi Data And Analytics Pvt Ltd
# 1073  Senior Data Scientist                       Bigshyft Hiring for Zupee
# 1320  Senior Data Scientist                            Sysvine Technologies
#
# ...

# %% [markdown]
# # apply () method

# %%
s = pd.Series(["Dev_joshi","Aman_Kumar","Ayush_Khan","Vansh_Sharma"])
s
# Out:
# 0       Dev_joshi
# 1      Aman_Kumar
# 2      Ayush_Khan
# 3    Vansh_Sharma
# dtype: object

# %% [markdown]
# **using apply functon over a series**

# %%
s = s.apply(lambda x:x.replace("_"," "))

# %% [markdown]
# **Applying a transformation across all the values of certain columns**

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("/kaggle/input/data-science-jobs-in-india/naukri_data_science_jobs_india.csv")
data.head()
# Out:
#                                             Job_Role            Company  \
# 0                              Senior Data Scientist                UPL
# 1                              Senior Data Scientist            Walmart
# 2  Applied Data Scientist / ML Senior Engineer (P...  SAP India Pvt.Ltd
# 3                                     Data Scientist                UPL
# 4                                     Data Scientist            Walmart
#
#                                   Location Job Experience  \
# 0  Bangalore/Bengaluru, Mumbai (All Areas)            3-6
# 1                      Bangalore/Bengaluru            5-9
# 2                      Bangalore/Bengaluru           5-10
# 3  Bangalore/Bengaluru, Mumbai (All Areas)            1-4
# 4                      Bangalore/Bengaluru            4-8
#
#                                   Skills/Description
# 0  python, MLT, statistical modeling, machine lea...
# 1  Data Science, Machine learning, Python, Azure,...
# ...

# %%
data["Salary"] = np.random.randint(400000,4000000,12000)

# %%
data.head()
# Out:
#                                             Job_Role            Company  \
# 0                              Senior Data Scientist                UPL
# 1                              Senior Data Scientist            Walmart
# 2  Applied Data Scientist / ML Senior Engineer (P...  SAP India Pvt.Ltd
# 3                                     Data Scientist                UPL
# 4                                     Data Scientist            Walmart
#
#                                   Location Job Experience  \
# 0  Bangalore/Bengaluru, Mumbai (All Areas)            3-6
# 1                      Bangalore/Bengaluru            5-9
# 2                      Bangalore/Bengaluru           5-10
# 3  Bangalore/Bengaluru, Mumbai (All Areas)            1-4
# 4                      Bangalore/Bengaluru            4-8
#
#                                   Skills/Description   Salary
# 0  python, MLT, statistical modeling, machine lea...   432898
# ...

# %%
data["Salary"] = data["Salary"].apply(lambda x:"Rs" + str(x))

# %%
data
# Out:
#                                                 Job_Role  \
# 0                                  Senior Data Scientist
# 1                                  Senior Data Scientist
# 2      Applied Data Scientist / ML Senior Engineer (P...
# 3                                         Data Scientist
# 4                                         Data Scientist
# ...                                                  ...
# 11995                Tech Lead/Architect ( Contractual )
# 11996                               Tech Lead / POD Lead
# 11997     Java Full Stack Developer - Hibernate / Spring
# 11998                                  Tech Lead - Azure
# 11999            Full Stack Developer - Machine Learning
#
#                                   Company  \
# 0                                     UPL
# 1                                 Walmart
# 2                       SAP India Pvt.Ltd
# 3                                     UPL
# 4                                 Walmart
# ...

# %%
def band(x):
    if x > 2000000:
        return "A"
    elif x > 1000000:
        return "B"
    else:
        return "C"

# %%
data["category"] = data["Salary"].apply(band)

# %%
data
# Out:
#                                                 Job_Role  \
# 0                                  Senior Data Scientist
# 1                                  Senior Data Scientist
# 2      Applied Data Scientist / ML Senior Engineer (P...
# 3                                         Data Scientist
# 4                                         Data Scientist
# ...                                                  ...
# 11995                Tech Lead/Architect ( Contractual )
# 11996                               Tech Lead / POD Lead
# 11997     Java Full Stack Developer - Hibernate / Spring
# 11998                                  Tech Lead - Azure
# 11999            Full Stack Developer - Machine Learning
#
#                                   Company  \
# 0                                     UPL
# 1                                 Walmart
# 2                       SAP India Pvt.Ltd
# 3                                     UPL
# 4                                 Walmart
# ...

# %% [markdown]
# **Applying the transformation to a particulare row**

# %%
def flage(x):
    loc = x["Location"]
     
    exp = x["Job Experience"]
    if loc in ["Bengaluru","Bangalore","Bangalore/Bengaluru"] and exp == "3-5":
        return "Yes"
    else:
        return "no"

# %%
data["Apply Or Not"] = data.apply(flage,axis = 1)

# %%
data["Apply Or Not"].value_counts()
# Out:
# Apply Or Not
# no     11798
# Yes      202
# Name: count, dtype: int64
