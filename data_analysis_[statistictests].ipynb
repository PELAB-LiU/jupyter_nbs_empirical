# %% [markdown]
# # Notebook crash analysis - statistic tests

# %% [markdown]
# ## Chi-square test
#
# An often quoted guideline for the validity of this calculation is that the test should be used only if the observed and expected frequencies in each cell are at least 5.
#
#     p-value<0.05 -> reject the null hypothesis (there s no difference between the two distributions)-> the two dist are statistically different
#     p-value>0.05 -> cannot reject the null, not different
#
# [scipy.stats.chi2_contingency](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.chi2_contingency.html)
#
# [Chi-squared_test](https://en.wikipedia.org/wiki/Chi-squared_test)
#
# [color map](https://matplotlib.org/stable/users/explain/colors/colormaps.html)

# %%
# import importlib
# importlib.reload(visualization_util)
# import utils.visualization_util as visualization_util

# %%
import pandas as pd
import utils.config as config
import utils.visualization_util as visualization_util
from IPython.display import display

# summed config
# config
df_mlerr_label_config_sum = pd.read_excel(config.path_default.joinpath('Manual_labeling/cluster_sampled_labeled_config_sum.xlsx'), keep_default_na=False)
exclude_config = ["label_if_code_error_align", "label_if_error_chain", "label_if_runinfo_help", "other"] 
# label_if_error_chain is the same as root cause.nb specific-previous cell error, others are not used here
df_mlerr_label_config_sum.drop(exclude_config, axis=1, inplace=True)
# data
df_mlerr_labels_sum = pd.read_excel(config.path_default.joinpath('Manual_labeling/cluster_sampled_labeled_sum.xlsx'))
df_mlerr_labels_g_sum = df_mlerr_labels_sum[df_mlerr_labels_sum["nb_source"]==config.NB_SOURCE["github"]].reset_index(drop=True)
df_mlerr_labels_k_sum = df_mlerr_labels_sum[df_mlerr_labels_sum["nb_source"]==config.NB_SOURCE["kaggle"]].reset_index(drop=True)
del df_mlerr_labels_sum

print(df_mlerr_labels_g_sum.eid.nunique())
print(df_mlerr_labels_k_sum.eid.nunique())
# Out:
# path_default=WindowsPath('C:/Users/yirwa29/Downloads/data_jupyter_nbs_empirical')
# 390
# 356

# %%
# Summarize the statistics
# github stats
cluster_res_g_sum = visualization_util.statistics_labels(df_mlerr_label_config_sum, df_mlerr_labels_g_sum)
for label_key in df_mlerr_label_config_sum:
    cluster_res_g_sum[label_key] = pd.DataFrame.from_dict(cluster_res_g_sum[label_key]).rename_axis('cluster_id').reset_index()
# for all clusters    
cluster_res_g_sum_weighted_sum = visualization_util.cal_weighted_sum(df_mlerr_label_config_sum, cluster_res_g_sum)

# kaggle stats
cluster_res_k_sum = visualization_util.statistics_labels(df_mlerr_label_config_sum, df_mlerr_labels_k_sum)
for label_key in df_mlerr_label_config_sum:
    cluster_res_k_sum[label_key] = pd.DataFrame.from_dict(cluster_res_k_sum[label_key]).rename_axis('cluster_id').reset_index()
cluster_res_k_sum_weighted_sum = visualization_util.cal_weighted_sum(df_mlerr_label_config_sum, cluster_res_k_sum)

# %%
for label_key in df_mlerr_label_config_sum:
    visualization_util.chisquare_test(cluster_res_g_sum_weighted_sum[label_key], cluster_res_k_sum_weighted_sum[label_key], label_key)
# Out:
# label_root_cause
# Removed number of features due to few(<5) data points: 1 1
# Chi2ContingencyResult: pvalue is  0.6621520888072709 (Not statistically different)
#
# label_ML_pipeline
# Removed number of features due to few(<5) data points: 0 0
# Chi2ContingencyResult: pvalue is  0.0016431066333584443 (Statistically different)
#
# label_if_ML_bug
# Removed number of features due to few(<5) data points: 0 0
# Chi2ContingencyResult: pvalue is  0.003718985802780076 (Statistically different)
#
# label_refined_exp_type
# Removed number of features due to few(<5) data points: 3 3
# Chi2ContingencyResult: pvalue is  0.3875112537588797 (Not statistically different)

# %%
# exception types
# top 10 + other (remainings)

cluster_res_exp_type_sum_weighted_sum = {x: cluster_res_k_sum_weighted_sum['label_refined_exp_type'].get(x, 0) + cluster_res_g_sum_weighted_sum['label_refined_exp_type'].get(x, 0)
                                         for x in set(cluster_res_k_sum_weighted_sum['label_refined_exp_type']).union(cluster_res_g_sum_weighted_sum['label_refined_exp_type'])}
df_cluster_res_exp_type_sum = pd.DataFrame(cluster_res_exp_type_sum_weighted_sum, index=["Combined"]).T.sort_values(by="Combined", ascending=False)

df_cluster_res_exp_type_kg = pd.DataFrame([cluster_res_k_sum_weighted_sum['label_refined_exp_type'],
                   cluster_res_g_sum_weighted_sum['label_refined_exp_type']]).T.rename(columns={0: 'Kaggle', 1: 'GitHub'})
# df_cluster_res_exp_type_kg
df_cluster_res_exp_type_kg = pd.concat([df_cluster_res_exp_type_sum, df_cluster_res_exp_type_kg], axis=1)
# df_cluster_res_exp_type_kg.loc['total']= df_cluster_res_exp_type_kg.sum()

df_cluster_res_exp_type_kg.index.name = "Exception type"
display(df_cluster_res_exp_type_kg[["Combined","GitHub","Kaggle"]])
# Out:
#                             Combined  GitHub  Kaggle
# Exception type
# variable not found               133      72      61
# invalid argument                  73      40      33
# io error                          72      35      37
# module not found                  60      38      22
# attribute error                   52      29      23
# key error                         50      21      29
# value error                       43      19      24
# tensor shape mismatch             41      18      23
# type error                        40      24      16
# index error                       29      17      12
# name error                        29      11      18
# data value violation              26      15      11
# OOM                               16       5      11
# environment error                 16       8       8
# other                             16      10       6
# request error                     13       8       5
# unsupported broadcast             12       5       7
# runtime error                     11       7       4
# feature name mismatch              9       6       3
# model initialization error         5       2       3

# %%
# percentages
(df_cluster_res_exp_type_kg/df_cluster_res_exp_type_kg.sum()*100).round(2)[["Combined","GitHub","Kaggle"]]
# Out:
#                             Combined  GitHub  Kaggle
# Exception type
# variable not found             17.83   18.46   17.13
# invalid argument                9.79   10.26    9.27
# io error                        9.65    8.97   10.39
# module not found                8.04    9.74    6.18
# attribute error                 6.97    7.44    6.46
# key error                       6.70    5.38    8.15
# value error                     5.76    4.87    6.74
# tensor shape mismatch           5.50    4.62    6.46
# type error                      5.36    6.15    4.49
# index error                     3.89    4.36    3.37
# name error                      3.89    2.82    5.06
# data value violation            3.49    3.85    3.09
# OOM                             2.14    1.28    3.09
# environment error               2.14    2.05    2.25
# other                           2.14    2.56    1.69
# request error                   1.74    2.05    1.40
# unsupported broadcast           1.61    1.28    1.97
# runtime error                   1.47    1.79    1.12
# feature name mismatch           1.21    1.54    0.84
# model initialization error      0.67    0.51    0.84

# %%
# calculate correlation between rc and exp
df_grouped_g = df_mlerr_labels_g_sum.groupby("label_refined_exp_type")["label_root_cause"].value_counts().unstack("label_root_cause")
df_grouped_g = df_grouped_g.fillna(0)
display(df_grouped_g)

df_grouped_k = df_mlerr_labels_k_sum.groupby("label_refined_exp_type")["label_root_cause"].value_counts().unstack("label_root_cause")
df_grouped_k = df_grouped_k.fillna(0)
display(df_grouped_k)
# Out:
# label_root_cause            API misuse  ML model confusion  NB specific  \
# label_refined_exp_type
# OOM                                0.0                 0.0          0.0
# attribute error                   13.0                 0.0          2.0
# data value violation               3.0                 0.0          0.0
# environment error                  1.0                 0.0          0.0
# feature name mismatch              2.0                 1.0          0.0
# index error                        4.0                 1.0          0.0
# invalid argument                  27.0                 2.0          0.0
# io error                           3.0                 0.0          1.0
# key error                          4.0                 0.0          0.0
# model initialization error         0.0                 0.0          1.0
# module not found                   0.0                 0.0         13.0
# name error                         0.0                 0.0          6.0
# other                              1.0                 0.0          0.0
# request error                      0.0                 0.0          0.0
# runtime error                      1.0                 0.0          0.0
# tensor shape mismatch              4.0                 1.0          2.0
# type error                        11.0                 0.0          1.0
# unsupported broadcast              0.0                 0.0          0.0
# value error                        7.0                 1.0          1.0
# variable not found                 1.0                 0.0         48.0
#
# label_root_cause            data confusion  environment setting  \
# label_refined_exp_type
# OOM                                    0.0                  0.0
# attribute error                        3.0                  3.0
# data value violation                  10.0                  1.0
# environment error                      0.0                  6.0
# feature name mismatch                  3.0                  0.0
# index error                            8.0                  0.0
# invalid argument                       7.0                  0.0
# io error                               1.0                 27.0
# key error                             13.0                  0.0
# model initialization error             0.0                  0.0
# module not found                       0.0                 22.0
# name error                             0.0                  0.0
# other                                  2.0                  2.0
# request error                          1.0                  6.0
# runtime error                          0.0                  2.0
# tensor shape mismatch                  7.0                  0.0
# type error                             4.0                  1.0
# unsupported broadcast                  1.0                  0.0
# value error                            6.0                  0.0
# variable not found                     0.0                  0.0
#
# label_root_cause            implementation error  insufficient resource  \
# label_refined_exp_type
# OOM                                          0.0                    5.0
# attribute error                              6.0                    0.0
# data value violation                         0.0                    0.0
# environment error                            1.0                    0.0
# feature name mismatch                        0.0                    0.0
# index error                                  4.0                    0.0
# invalid argument                             3.0                    0.0
# io error                                     3.0                    0.0
# key error                                    3.0                    0.0
# model initialization error                   0.0                    0.0
# module not found                             3.0                    0.0
# name error                                   5.0                    0.0
# other                                        2.0                    1.0
# request error                                0.0                    0.0
# runtime error                                3.0                    0.0
# tensor shape mismatch                        1.0                    0.0
# type error                                   5.0                    0.0
# unsupported broadcast                        4.0                    0.0
# value error                                  3.0                    0.0
# variable not found                          22.0                    0.0
#
# label_root_cause            library cause  unknown
# label_refined_exp_type
# OOM                                   0.0      0.0
# attribute error                       1.0      1.0
# data value violation                  0.0      1.0
# environment error                     0.0      0.0
# feature name mismatch                 0.0      0.0
# index error                           0.0      0.0
# invalid argument                      0.0      1.0
# io error                              0.0      0.0
# key error                             0.0      1.0
# model initialization error            0.0      1.0
# module not found                      0.0      0.0
# name error                            0.0      0.0
# other                                 0.0      2.0
# request error                         0.0      1.0
# runtime error                         0.0      1.0
# tensor shape mismatch                 0.0      3.0
# type error                            0.0      2.0
# unsupported broadcast                 0.0      0.0
# value error                           0.0      1.0
# variable not found                    0.0      1.0
# label_root_cause            API misuse  ML model confusion  NB specific  \
# label_refined_exp_type
# OOM                                0.0                 0.0          0.0
# attribute error                   10.0                 1.0          1.0
# data value violation               5.0                 0.0          1.0
# environment error                  0.0                 0.0          1.0
# feature name mismatch              0.0                 0.0          0.0
# index error                        3.0                 1.0          1.0
# invalid argument                  21.0                 3.0          0.0
# io error                           3.0                 0.0          0.0
# key error                          7.0                 0.0          8.0
# model initialization error         1.0                 0.0          1.0
# module not found                   0.0                 0.0          9.0
# name error                         0.0                 0.0         11.0
# other                              0.0                 0.0          0.0
# request error                      0.0                 0.0          0.0
# runtime error                      0.0                 0.0          0.0
# tensor shape mismatch              8.0                 4.0          0.0
# type error                         6.0                 1.0          0.0
# unsupported broadcast              2.0                 0.0          0.0
# value error                        8.0                 1.0          0.0
# variable not found                 0.0                 0.0         37.0
#
# label_root_cause            data confusion  environment setting  \
# label_refined_exp_type
# OOM                                    0.0                  0.0
# attribute error                        3.0                  1.0
# data value violation                   3.0                  0.0
# environment error                      0.0                  6.0
# feature name mismatch                  0.0                  0.0
# index error                            5.0                  0.0
# invalid argument                       3.0                  0.0
# io error                               1.0                 33.0
# key error                             12.0                  0.0
# model initialization error             0.0                  0.0
# module not found                       0.0                 10.0
# name error                             0.0                  0.0
# other                                  0.0                  0.0
# request error                          0.0                  5.0
# runtime error                          1.0                  0.0
# tensor shape mismatch                  7.0                  0.0
# type error                             4.0                  0.0
# unsupported broadcast                  5.0                  0.0
# value error                           12.0                  0.0
# variable not found                     0.0                  0.0
#
# label_root_cause            implementation error  insufficient resource  \
# label_refined_exp_type
# OOM                                          0.0                   11.0
# attribute error                              4.0                    0.0
# data value violation                         1.0                    0.0
# environment error                            0.0                    0.0
# feature name mismatch                        3.0                    0.0
# index error                                  2.0                    0.0
# invalid argument                             2.0                    0.0
# io error                                     0.0                    0.0
# key error                                    2.0                    0.0
# model initialization error                   1.0                    0.0
# module not found                             2.0                    0.0
# name error                                   6.0                    0.0
# other                                        1.0                    0.0
# request error                                0.0                    0.0
# runtime error                                0.0                    0.0
# tensor shape mismatch                        3.0                    0.0
# type error                                   4.0                    0.0
# unsupported broadcast                        0.0                    0.0
# value error                                  3.0                    0.0
# variable not found                          24.0                    0.0
#
# label_root_cause            library cause  unknown
# label_refined_exp_type
# OOM                                   0.0      0.0
# attribute error                       3.0      0.0
# data value violation                  0.0      1.0
# environment error                     1.0      0.0
# feature name mismatch                 0.0      0.0
# index error                           0.0      0.0
# invalid argument                      2.0      2.0
# io error                              0.0      0.0
# key error                             0.0      0.0
# model initialization error            0.0      0.0
# module not found                      0.0      1.0
# name error                            0.0      1.0
# other                                 1.0      4.0
# request error                         0.0      0.0
# runtime error                         0.0      3.0
# tensor shape mismatch                 1.0      0.0
# type error                            0.0      1.0
# unsupported broadcast                 0.0      0.0
# value error                           0.0      0.0
# variable not found                    0.0      0.0

# %%
# # chisquare_test of each root cause-exp distribution between github and kaggle
# for id_exp in range(df_grouped_g.shape[0]):
#     visualization_util.chisquare_test(df_grouped_g.iloc[id_exp], df_grouped_k.iloc[id_exp], df_grouped_k.index[id_exp], min_dp=5)

# %% [markdown]
# Too few samples for chi-square test to work properly.
#
# We try Barnard's exact test on "each root cause + the rest of the root causes" between GitHub and Kaggle, then do Bonferroni Correction.
#
# Barnard's exact test: https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.barnard_exact.html
#
# Bonferroni Correction
#
#     How it works: This is a simple and conservative method to adjust for multiple comparisons. The idea is to divide the significance level by the number of tests (m) to control the family-wise error rate (FWER).
#     Procedure:
#     If you conduct x tests (e.g., one test for each category vs. the rest), adjust the significance threshold by using 𝛼/x.
#         Which means p-value needs to be p<0.05/x (for CI=95%)
#     Advantages: Controls the probability of making even a single Type I error (false positive).
#     Disadvantages: Very conservative, which can increase the chance of missing true effects (i.e., high Type II error).

# %%
# barnard's exact test + Bonferroni Correction
from scipy.stats import chi2_contingency, barnard_exact

for id_exp in range(df_grouped_g.shape[0]):
    label_exp = df_grouped_g.index[id_exp]
    print("testing ---",label_exp)
    correction = df_grouped_g.shape[1]
    is_different = False
    for id_rc in range(df_grouped_g.shape[1]):
        label_rc = df_grouped_g.columns[id_rc]
        print("    --",label_rc, "against the rest")
        count_rc_g = df_grouped_g.iloc[id_exp][label_rc]
        count_rc_k = df_grouped_k.iloc[id_exp][label_rc]
        table_label_key_gk = [[count_rc_g,count_rc_k], # number of rc
                              [df_grouped_g.iloc[id_exp].sum()-count_rc_g, # number of the rest of rcs
                               df_grouped_k.iloc[id_exp].sum()-count_rc_k]]
        pvalue_be = barnard_exact(table_label_key_gk).pvalue
        print("        p-value is", pvalue_be, "corrected p-value is", pvalue_be*correction)
        if pvalue_be*correction < 0.05:
            print("Found enough evidence to reject the null hypothesis: they are statistically different")
            is_different = True
            continue
    if not is_different:
        print("-->Not statistically different\n")
# Out:
# testing --- OOM
#     -- API misuse against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- ML model confusion against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- NB specific against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- data confusion against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- environment setting against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- implementation error against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- insufficient resource against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- library cause against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- unknown against the rest
#         p-value is 1.0 corrected p-value is 9.0
# -->Not statistically different
#
# testing --- attribute error
#     -- API misuse against the rest
#         p-value is 0.9627921301044075 corrected p-value is 8.665129170939666
#     -- ML model confusion against the rest
#         p-value is 0.35241979224349257 corrected p-value is 3.171778130191433
#     -- NB specific against the rest
#         p-value is 0.716965814115694 corrected p-value is 6.452692327041246
#     -- data confusion against the rest
#         p-value is 0.7916164723325495 corrected p-value is 7.124548250992945
#     -- environment setting against the rest
#         p-value is 0.5887038503659002 corrected p-value is 5.298334653293102
#     -- implementation error against the rest
#         p-value is 0.8193575357263223 corrected p-value is 7.3742178215369005
#     -- insufficient resource against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- library cause against the rest
#         p-value is 0.2108445244467782 corrected p-value is 1.8976007200210039
#     -- unknown against the rest
#         p-value is 0.5154944179438066 corrected p-value is 4.639449761494259
# -->Not statistically different
#
# testing --- data value violation
#     -- API misuse against the rest
#         p-value is 0.19702820522304793 corrected p-value is 1.7732538470074313
#     -- ML model confusion against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- NB specific against the rest
#         p-value is 0.3312941488803415 corrected p-value is 2.9816473399230734
#     -- data confusion against the rest
#         p-value is 0.056584477424621804 corrected p-value is 0.5092602968215962
#     -- environment setting against the rest
#         p-value is 0.5654437271652475 corrected p-value is 5.088993544487227
#     -- implementation error against the rest
#         p-value is 0.3312941488803415 corrected p-value is 2.9816473399230734
#     -- insufficient resource against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- library cause against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- unknown against the rest
#         p-value is 0.9136453461219389 corrected p-value is 8.22280811509745
# -->Not statistically different
#
# testing --- environment error
#     -- API misuse against the rest
#         p-value is 0.5213387187746641 corrected p-value is 4.692048468971977
#     -- ML model confusion against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- NB specific against the rest
#         p-value is 0.5213387187746641 corrected p-value is 4.692048468971977
#     -- data confusion against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- environment setting against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- implementation error against the rest
#         p-value is 0.5213387187746641 corrected p-value is 4.692048468971977
#     -- insufficient resource against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- library cause against the rest
#         p-value is 0.5213387187746641 corrected p-value is 4.692048468971977
#     -- unknown against the rest
#         p-value is 1.0 corrected p-value is 9.0
# -->Not statistically different
#
# testing --- feature name mismatch
#     -- API misuse against the rest
#         p-value is 0.3651519180325265 corrected p-value is 3.2863672622927385
#     -- ML model confusion against the rest
#         p-value is 0.5794816816365338 corrected p-value is 5.215335134728804
#     -- NB specific against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- data confusion against the rest
#         p-value is 0.2578125000000001 corrected p-value is 2.320312500000001
#     -- environment setting against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- implementation error against the rest
#         p-value is 0.003906250000000004 corrected p-value is 0.03515625000000004
# Found enough evidence to reject the null hypothesis: they are statistically different
#     -- insufficient resource against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- library cause against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- unknown against the rest
#         p-value is 1.0 corrected p-value is 9.0
# testing --- index error
#     -- API misuse against the rest
#         p-value is 0.960047216558356 corrected p-value is 8.640424949025205
#     -- ML model confusion against the rest
#         p-value is 0.9131523616517301 corrected p-value is 8.21837125486557
#     -- NB specific against the rest
#         p-value is 0.331386097746595 corrected p-value is 2.982474879719355
#     -- data confusion against the rest
#         p-value is 0.8223693725031263 corrected p-value is 7.401324352528136
#     -- environment setting against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- implementation error against the rest
#         p-value is 0.705931948756028 corrected p-value is 6.353387538804252
#     -- insufficient resource against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- library cause against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- unknown against the rest
#         p-value is 1.0 corrected p-value is 9.0
# -->Not statistically different
#
# testing --- invalid argument
#     -- API misuse against the rest
#         p-value is 0.7537587591976932 corrected p-value is 6.783828832779239
#     -- ML model confusion against the rest
#         p-value is 0.6039723523602663 corrected p-value is 5.435751171242396
#     -- NB specific against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- data confusion against the rest
#         p-value is 0.35719825443876024 corrected p-value is 3.214784289948842
#     -- environment setting against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- implementation error against the rest
#         p-value is 0.8643194501659242 corrected p-value is 7.778875051493317
#     -- insufficient resource against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- library cause against the rest
#         p-value is 0.15147768493320463 corrected p-value is 1.3632991643988417
#     -- unknown against the rest
#         p-value is 0.5900751125390831 corrected p-value is 5.310676012851747
# -->Not statistically different
#
# testing --- io error
#     -- API misuse against the rest
#         p-value is 0.9997857222716046 corrected p-value is 8.998071500444441
#     -- ML model confusion against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- NB specific against the rest
#         p-value is 0.36108094263432766 corrected p-value is 3.249728483708949
#     -- data confusion against the rest
#         p-value is 0.9999994135380553 corrected p-value is 8.999994721842498
#     -- environment setting against the rest
#         p-value is 0.21992003992122072 corrected p-value is 1.9792803592909864
#     -- implementation error against the rest
#         p-value is 0.07652900056499275 corrected p-value is 0.6887610050849348
#     -- insufficient resource against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- library cause against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- unknown against the rest
#         p-value is 1.0 corrected p-value is 9.0
# -->Not statistically different
#
# testing --- key error
#     -- API misuse against the rest
#         p-value is 0.7036728974485436 corrected p-value is 6.3330560770368916
#     -- ML model confusion against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- NB specific against the rest
#         p-value is 0.010530429766176535 corrected p-value is 0.09477386789558881
#     -- data confusion against the rest
#         p-value is 0.1584228573464548 corrected p-value is 1.4258057161180933
#     -- environment setting against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- implementation error against the rest
#         p-value is 0.5688212250193183 corrected p-value is 5.119391025173865
#     -- insufficient resource against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- library cause against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- unknown against the rest
#         p-value is 0.3371979471280002 corrected p-value is 3.034781524152002
# -->Not statistically different
#
# testing --- model initialization error
#     -- API misuse against the rest
#         p-value is 0.5681818181818088 corrected p-value is 5.113636363636279
#     -- ML model confusion against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- NB specific against the rest
#         p-value is 0.7740885918297856 corrected p-value is 6.966797326468071
#     -- data confusion against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- environment setting against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- implementation error against the rest
#         p-value is 0.5681818181818088 corrected p-value is 5.113636363636279
#     -- insufficient resource against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- library cause against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- unknown against the rest
#         p-value is 0.375 corrected p-value is 3.375
# -->Not statistically different
#
# testing --- module not found
#     -- API misuse against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- ML model confusion against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- NB specific against the rest
#         p-value is 0.6313102249584651 corrected p-value is 5.681792024626186
#     -- data confusion against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- environment setting against the rest
#         p-value is 0.4136492492718895 corrected p-value is 3.722843243447006
#     -- implementation error against the rest
#         p-value is 0.9221955155157644 corrected p-value is 8.299759639641879
#     -- insufficient resource against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- library cause against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- unknown against the rest
#         p-value is 0.22743680333506341 corrected p-value is 2.046931230015571
# -->Not statistically different
#
# testing --- name error
#     -- API misuse against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- ML model confusion against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- NB specific against the rest
#         p-value is 0.7876877638591996 corrected p-value is 7.089189874732797
#     -- data confusion against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- environment setting against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- implementation error against the rest
#         p-value is 0.5687798394675071 corrected p-value is 5.119018555207564
#     -- insufficient resource against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- library cause against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- unknown against the rest
#         p-value is 0.5669789762191586 corrected p-value is 5.102810785972427
# -->Not statistically different
#
# testing --- other
#     -- API misuse against the rest
#         p-value is 0.5633000631454275 corrected p-value is 5.069700568308847
#     -- ML model confusion against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- NB specific against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- data confusion against the rest
#         p-value is 0.32914643265090987 corrected p-value is 2.962317893858189
#     -- environment setting against the rest
#         p-value is 0.32914643265090987 corrected p-value is 2.962317893858189
#     -- implementation error against the rest
#         p-value is 0.9203468046224416 corrected p-value is 8.283121241601973
#     -- insufficient resource against the rest
#         p-value is 0.5633000631454275 corrected p-value is 5.069700568308847
#     -- library cause against the rest
#         p-value is 0.23419434776673134 corrected p-value is 2.107749129900582
#     -- unknown against the rest
#         p-value is 0.07839965820312508 corrected p-value is 0.7055969238281258
# -->Not statistically different
#
# testing --- request error
#     -- API misuse against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- ML model confusion against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- NB specific against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- data confusion against the rest
#         p-value is 0.5588589905928771 corrected p-value is 5.029730915335894
#     -- environment setting against the rest
#         p-value is 0.3227352018497885 corrected p-value is 2.9046168166480966
#     -- implementation error against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- insufficient resource against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- library cause against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- unknown against the rest
#         p-value is 0.5588589905928771 corrected p-value is 5.029730915335894
# -->Not statistically different
#
# testing --- runtime error
#     -- API misuse against the rest
#         p-value is 0.5590608081985768 corrected p-value is 5.031547273787192
#     -- ML model confusion against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- NB specific against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- data confusion against the rest
#         p-value is 0.2182732711971037 corrected p-value is 1.9644594407739335
#     -- environment setting against the rest
#         p-value is 0.3750114518541903 corrected p-value is 3.375103066687713
#     -- implementation error against the rest
#         p-value is 0.14281062056982918 corrected p-value is 1.2852955851284626
#     -- insufficient resource against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- library cause against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- unknown against the rest
#         p-value is 0.059679094243481216 corrected p-value is 0.537111848191331
# -->Not statistically different
#
# testing --- tensor shape mismatch
#     -- API misuse against the rest
#         p-value is 0.5154151660431374 corrected p-value is 4.638736494388237
#     -- ML model confusion against the rest
#         p-value is 0.32014174841568216 corrected p-value is 2.8812757357411396
#     -- NB specific against the rest
#         p-value is 0.10942495532996703 corrected p-value is 0.9848245979697032
#     -- data confusion against the rest
#         p-value is 0.6068256561424018 corrected p-value is 5.461430905281616
#     -- environment setting against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- implementation error against the rest
#         p-value is 0.5875439034533303 corrected p-value is 5.287895131079972
#     -- insufficient resource against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- library cause against the rest
#         p-value is 0.515415163254597 corrected p-value is 4.6387364692913735
#     -- unknown against the rest
#         p-value is 0.04441877433906774 corrected p-value is 0.39976896905160964
# -->Not statistically different
#
# testing --- type error
#     -- API misuse against the rest
#         p-value is 0.6326028154439152 corrected p-value is 5.693425338995237
#     -- ML model confusion against the rest
#         p-value is 0.24195757475578591 corrected p-value is 2.1776181728020734
#     -- NB specific against the rest
#         p-value is 0.5676674036668758 corrected p-value is 5.109006633001883
#     -- data confusion against the rest
#         p-value is 0.6029201264258527 corrected p-value is 5.4262811378326745
#     -- environment setting against the rest
#         p-value is 0.5676674036668758 corrected p-value is 5.109006633001883
#     -- implementation error against the rest
#         p-value is 0.7868007587453258 corrected p-value is 7.081206828707932
#     -- insufficient resource against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- library cause against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- unknown against the rest
#         p-value is 0.9105224008887972 corrected p-value is 8.194701607999175
# -->Not statistically different
#
# testing --- unsupported broadcast
#     -- API misuse against the rest
#         p-value is 0.2241036750859433 corrected p-value is 2.0169330757734896
#     -- ML model confusion against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- NB specific against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- data confusion against the rest
#         p-value is 0.11181640625000012 corrected p-value is 1.006347656250001
#     -- environment setting against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- implementation error against the rest
#         p-value is 0.006347656250000003 corrected p-value is 0.05712890625000002
#     -- insufficient resource against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- library cause against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- unknown against the rest
#         p-value is 1.0 corrected p-value is 9.0
# -->Not statistically different
#
# testing --- value error
#     -- API misuse against the rest
#         p-value is 0.8439086652794785 corrected p-value is 7.5951779875153065
#     -- ML model confusion against the rest
#         p-value is 0.9633279293911354 corrected p-value is 8.66995136452022
#     -- NB specific against the rest
#         p-value is 0.35072354554404156 corrected p-value is 3.156511909896374
#     -- data confusion against the rest
#         p-value is 0.253814298491097 corrected p-value is 2.284328686419873
#     -- environment setting against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- implementation error against the rest
#         p-value is 0.7888347612905138 corrected p-value is 7.099512851614624
#     -- insufficient resource against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- library cause against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- unknown against the rest
#         p-value is 0.35072354554404156 corrected p-value is 3.156511909896374
# -->Not statistically different
#
# testing --- variable not found
#     -- API misuse against the rest
#         p-value is 0.5157827458807457 corrected p-value is 4.642044712926711
#     -- ML model confusion against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- NB specific against the rest
#         p-value is 0.5916974860680942 corrected p-value is 5.325277374612848
#     -- data confusion against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- environment setting against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- implementation error against the rest
#         p-value is 0.35581537454114137 corrected p-value is 3.2023383708702724
#     -- insufficient resource against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- library cause against the rest
#         p-value is 1.0 corrected p-value is 9.0
#     -- unknown against the rest
#         p-value is 0.5157827458807457 corrected p-value is 4.642044712926711
# -->Not statistically different

# %%
mlbug = pd.DataFrame([cluster_res_k_sum_weighted_sum['label_if_ML_bug'],
                   cluster_res_g_sum_weighted_sum['label_if_ML_bug']]).T.rename(columns={0: 'Kaggle', 1: 'GitHub'})
mlbug['Kaggle']=(mlbug['Kaggle']/mlbug['Kaggle'].sum()*100).round(2)
mlbug['GitHub']=(mlbug['GitHub']/mlbug['GitHub'].sum()*100).round(2)

mlbug.index=["ML bug", "Python bug"]
mlbug.index.name = 'If ML bug'
mlbug[["GitHub","Kaggle"]]
# Out:
#             GitHub  Kaggle
# If ML bug
# ML bug       62.82   73.03
# Python bug   37.18   26.97

# %%
df_grouped_g = df_mlerr_labels_g_sum.groupby("label_if_ML_bug")["label_root_cause"].value_counts().unstack("label_root_cause")
df_grouped_g = df_grouped_g.fillna(0).astype(int)
df_grouped_k = df_mlerr_labels_k_sum.groupby("label_if_ML_bug")["label_root_cause"].value_counts().unstack("label_root_cause")
df_grouped_k = df_grouped_k.fillna(0).astype(int)
display(df_grouped_g)
display(df_grouped_k)
# Out:
# label_root_cause  API misuse  ML model confusion  NB specific  data confusion  \
# label_if_ML_bug
# ML bug                    62                   6           48              51
# python bug                20                   0           27              15
#
# label_root_cause  environment setting  implementation error  \
# label_if_ML_bug
# ML bug                             32                    28
# python bug                         38                    40
#
# label_root_cause  insufficient resource  library cause  unknown
# label_if_ML_bug
# ML bug                                6              1       11
# python bug                            0              0        5
# label_root_cause  API misuse  ML model confusion  NB specific  data confusion  \
# label_if_ML_bug
# ML bug                    64                  11           54              49
# python bug                10                   0           16               7
#
# label_root_cause  environment setting  implementation error  \
# label_if_ML_bug
# ML bug                             27                    30
# python bug                         28                    28
#
# label_root_cause  insufficient resource  library cause  unknown
# label_if_ML_bug
# ML bug                               11              5        9
# python bug                            0              3        4

# %%
# chisquare_test of each root cause-ml bug distribution between github and kaggle
for id_mlbug in range(df_grouped_g.shape[0]):
    visualization_util.chisquare_test(df_grouped_g.iloc[id_mlbug], df_grouped_k.iloc[id_mlbug], df_grouped_k.index[id_mlbug], min_dp=5)
# Out:
# ML bug
# Removed number of features due to few(<5) data points: 1 1
# Chi2ContingencyResult: pvalue is  0.8004935161175339 (Not statistically different)
#
# python bug
# Removed number of features due to few(<5) data points: 4 4
# Chi2ContingencyResult: pvalue is  0.8440970374636387 (Not statistically different)

# %%
# chisquare_test of each root cause-ml bug distribution between ml bug and python bug
source_list = ["GitHub", "Kaggle", "Combined"]
df_grouped = df_grouped_g + df_grouped_k

visualization_util.chisquare_test(df_grouped_g.iloc[0], df_grouped_g.iloc[1], source_list[0], min_dp=5)
visualization_util.chisquare_test(df_grouped_k.iloc[0], df_grouped_k.iloc[1], source_list[1], min_dp=5)
visualization_util.chisquare_test(df_grouped.iloc[0], df_grouped.iloc[1], source_list[2], min_dp=5)
# Out:
# GitHub
# Removed number of features due to few(<5) data points: 3 3
# Chi2ContingencyResult: pvalue is  2.828375861513032e-06 (Statistically different)
#
# Kaggle
# Removed number of features due to few(<5) data points: 4 4
# Chi2ContingencyResult: pvalue is  2.6542797006796473e-08 (Statistically different)
#
# Combined
# Removed number of features due to few(<5) data points: 3 3
# Chi2ContingencyResult: pvalue is  2.9744826189098034e-14 (Statistically different)
# 2.9744826189098034e-14

# %%
df_grouped_g = df_mlerr_labels_g_sum.groupby("label_ML_pipeline")["label_if_ML_bug"].value_counts().unstack("label_if_ML_bug")
df_grouped_k = df_mlerr_labels_k_sum.groupby("label_ML_pipeline")["label_if_ML_bug"].value_counts().unstack("label_if_ML_bug")[["ML bug","python bug"]]
display(df_grouped_g)
display(df_grouped_k)
# Out:
# label_if_ML_bug        ML bug  python bug
# label_ML_pipeline
# data preparation           75          72
# data visualization         35          20
# environment setup          15          21
# evaluation/prediction      41          16
# model construction         24           3
# training                   55          13
# label_if_ML_bug        ML bug  python bug
# label_ML_pipeline
# data preparation           71          28
# data visualization         33          13
# environment setup           3          16
# evaluation/prediction      58          22
# model construction         28           7
# training                   67          10

# %%
# Barnard exact test of ml bug distributions between github and kaggle for each pipeline
# because sample size of some is less than 5: environment setup(ML bug-Kaggle),model construction(python bug-GitHub)
for id_exp in range(df_grouped_g.shape[0]):
    visualization_util.barnard_test(df_grouped_g.iloc[id_exp], df_grouped_k.iloc[id_exp], df_grouped_k.index[id_exp])
# Out:
# data preparation
# Barnard exact result: pvalue is  0.0012216380039289166 (Statistically different)
#
# data visualization
# Barnard exact result: pvalue is  0.5156882022534633 (Not statistically different)
#
# environment setup
# Barnard exact result: pvalue is  0.05565227105055206 (Not statistically different)
#
# evaluation/prediction
# Barnard exact result: pvalue is  0.9652054509505578 (Not statistically different)
#
# model construction
# Barnard exact result: pvalue is  0.35433241349554634 (Not statistically different)
#
# training
# Barnard exact result: pvalue is  0.3582249872048062 (Not statistically different)

# %%
# post hoc analysis after a chi-square test
import pandas as pd
import numpy as np
from scipy.stats import chi2_contingency, norm

mlpp_g = cluster_res_g_sum_weighted_sum["label_ML_pipeline"].copy()
mlpp_k = cluster_res_k_sum_weighted_sum["label_ML_pipeline"].copy()

observed_df = pd.concat([pd.DataFrame.from_dict(mlpp_g, columns=["GitHub"],orient='index').T, pd.DataFrame.from_dict(mlpp_k, columns=["Kaggle"],orient='index').T])
chi_res = visualization_util.chisquare_test(observed_df.iloc[0], observed_df.iloc[1], "ML pipeline stages", res_all=True)
expected = chi_res.expected_freq
expected_df = pd.DataFrame(expected, columns=["GitHub","Kaggle"], index=observed_df.columns).T

residuals_std = ((observed_df.T.to_numpy()-expected)/np.sqrt(expected))
residuals_std_df = pd.DataFrame(residuals_std, columns=["GitHub","Kaggle"], index=observed_df.columns).T
# Out:
# ML pipeline stages
# Removed number of features due to few(<5) data points: 0 0
# Chi2ContingencyResult: pvalue is  0.0016431066333584443 (Statistically different)

# %%
# test which variables contribute more to the difference

import seaborn as sns
import matplotlib.pyplot as plt

residuals_std_df = residuals_std_df[config.order_mlpp]
plt.figure(figsize=(2,4))
cm_dp = sns.diverging_palette(220, 20, center="light", as_cmap=True)
rc_new = [config.mlpp2abbr[x] for x in residuals_std_df.columns]
s = sns.heatmap(residuals_std_df[config.order_mlpp].T, annot=True, yticklabels=rc_new, cmap=cm_dp, 
                center=0,vmin=-2, vmax=2)
s.set(xlabel='', ylabel='')
plt.savefig(config.path_plot_default.joinpath('mlpp_residuals.pdf'), bbox_inches='tight')
plt.show()
